# %%
#General Querry

import sqlite3

conn = sqlite3.connect('EstoreMonitoring.db')
cur = conn.cursor()
cur.execute("SELECT * FROM price")

prices = cur.fetchall()

for u in prices:
    print(u)
# Out:
# (1, '2025-10-21 09:32:11.038231', 'R$ 2.888,88', 'R$ 1.849,99', 1)
# (2, '2025-10-21 09:32:17.549503', 'R$ 299,90', 'R$ 249,90', 2)
# (3, '2025-10-21 09:32:30.786256', 'R$ 3.999,00', 'R$ 3.533,07', 3)
# (4, '2025-10-21 09:32:37.048704', 'R$ 5.161,18', 'R$ 4.463,07', 4)
# (5, '2025-10-21 11:40:25.144350', 'R$ 2.888,88', 'R$ 1.849,99', 5)
# (6, '2025-10-21 11:40:38.614501', 'R$ 299,90', 'R$ 249,90', 6)
# (7, '2025-10-21 11:40:44.333494', 'R$ 3.999,00', 'R$ 3.533,07', 7)
# (8, '2025-10-21 11:40:53.501369', 'R$ 5.161,18', 'R$ 4.463,07', 8)
